# %%
distributions = ['pois', 'gaus', 'chisq', 'wald', 'uni', 'binomial']

# %%
mymean=100
mysd=10

# %%
import numpy as np
import pylab as pl
import json, os
import matplotlib.mlab as ml
from scipy.stats import norm

mysize=2000/(np.array(range(1,200,2)))
#generating sample sizes between 10 and 2000

print (mysize, mysize.shape)
# Out:
# [2000  666  400  285  222  181  153  133  117  105   95   86   80   74   68
#    64   60   57   54   51   48   46   44   42   40   39   37   36   35   33
#    32   31   30   29   28   28   27   26   25   25   24   24   23   22   22
#    21   21   21   20   20   19   19   19   18   18   18   17   17   17   16
#    16   16   16   15   15   15   15   14   14   14   14   13   13   13   13
#    13   13   12   12   12   12   12   12   11   11   11   11   11   11   11
#    11   10   10   10   10   10   10   10   10   10] (100,)

# %%
md['chisq']={} 
for n in mysize:
    md['chisq'][n] = np.random.chisquare(mymean, size=n)
    
means = {}
means['chisq'] = {}
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['chisq'].iterkeys():
    means['chisq'][nn] = md['chisq'][nn].mean()
    axchisq_mu_n.plot(nn, means['chisq'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(mysize), max(mysize)],[df,df], 'k')

# %%
allmeans=[]
for n in means['chisq']:
    allmeans.append(means['chisq'][n])

pl.figure(figsize=(10,10))
bins = pl.hist(allmeans, 30, normed=1, facecolor='green', alpha=0.75)
pl.xlabel('sample mean')
pl.ylabel('N')

# %%
md['pois']={} 

for n in mysize:
    md['pois'][n] = np.random.poisson(mymean, size=n)
    
means = {}
means['pois'] = {}
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['pois'].iterkeys():
    means['pois'][nn] = md['pois'][nn].mean()
    axchisq_mu_n.plot(nn, means['pois'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(mysize), max(mysize)],[mymean,mymean], 'k')

# %%
allmeans=[]
for n in means['pois']:
    allmeans.append(means['pois'][n])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %%
md['gaus']={} 

for n in mysize:
    md['gaus'][n] = np.random.normal(mymean, mysd, size=n)
    
means = {}
means['gaus'] = {}
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['gaus'].iterkeys():
    means['gaus'][nn] = md['gaus'][nn].mean()
    axchisq_mu_n.plot(nn, means['gaus'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(mysize), max(mysize)],[mymean,mymean], 'k')

# %%
allmeans=[]
for n in means['gaus']:
    allmeans.append(means['gaus'][n])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %%
md['binomial']={} 

for n in mysize:
    md['binomial'][n] = np.random.binomial(200, 0.5, size=n)
    
means = {}
means['binomial'] = {}
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['binomial'].iterkeys():
    means['binomial'][nn] = md['binomial'][nn].mean()
    #and plot it
    axchisq_mu_n.plot(nn, means['binomial'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(mysize), max(mysize)],[mymean,mymean], 'k')

# %%
allmeans=[]
for n in means['binomial']:
    allmeans.append(means['binomial'][n])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %%
md['uni']={} 

for n in mysize:
    md['uni'][n] = np.random.uniform(0,200, size=n)
    
means = {}
means['uni'] = {}
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['uni'].iterkeys():
    means['uni'][nn] = md['uni'][nn].mean()
    axchisq_mu_n.plot(nn, means['uni'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(mysize), max(mysize)],[mymean,mymean], 'k')

# %%
allmeans=[]
for n in means['uni']:
    allmeans.append(means['uni'][n])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %%
md['wald']={} 

for n in mysize:
    md['wald'][n] = np.random.wald(100,10, size=n)
    
means = {}
means['wald'] = {}
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['wald'].iterkeys():
    means['wald'][nn] = md['wald'][nn].mean()
    axchisq_mu_n.plot(nn, means['wald'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(mysize), max(mysize)],[mymean,mymean], 'k')

# %%
allmeans=[]
for n in means['wald']:
    allmeans.append(means['wald'][n])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')
